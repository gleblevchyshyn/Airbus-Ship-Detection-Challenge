# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from skimage.io import imread
import matplotlib.pyplot as plt
import os
import tensorflow as tf
from Unet.metrics import dice_loss, dice_coff
from Unet.rle import montage_rgb, montage, masks_as_image, rle_decode
# Out:
# WARNING:tensorflow:From C:\Users\glebl\PycharmProjects\Airbus-Ship-Detection-Challenge\test_ai\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
BATCH_SIZE = 48
# downsampling in preprocessing
IMG_SCALING = (3, 3)
# number of validation images to use
VALID_IMG_COUNT = 900
# maximum number of steps_per_epoch in training
MAX_TRAIN_STEPS = 300

# %% [markdown]
# ## Dataset Preparation

# %%
train_image_dir = '../train_v2'
test_image_dir = '../test_v2'

# %%
train_df = pd.read_csv('../train_df.csv')
valid_df = pd.read_csv('../valid_df.csv')

# %%
def make_image_gen(in_df, batch_size=BATCH_SIZE):
    """
    
    :param in_df: Pandas DataFrame where paths to the images and encoded ground truth labels are stored
    :param batch_size: Batch size of created tf.data.Dataset
    :return: returns tf.data.Dataset created from generator
    """
    all_batches = list(in_df.groupby('ImageId'))
    
    def generator():
        while True:
            np.random.shuffle(all_batches)
            for c_img_id, c_masks in all_batches:
                rgb_path = os.path.join(train_image_dir, c_img_id)
                c_img = imread(rgb_path)
                c_mask = np.expand_dims(masks_as_image(c_masks['EncodedPixels'].values), -1)
                
                if IMG_SCALING is not None:
                    c_img = c_img[::IMG_SCALING[0], ::IMG_SCALING[1]]
                    c_mask = c_mask[::IMG_SCALING[0], ::IMG_SCALING[1]]
                
                yield c_img/255.0, c_mask

    dataset = tf.data.Dataset.from_generator(generator,
                                             output_signature=(tf.TensorSpec(shape=(None, None, 3), dtype=tf.float32),
                                                               tf.TensorSpec(shape=(None, None, 1), dtype=tf.uint8)))

    dataset = dataset.batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

# %%
train_ds = make_image_gen(train_df, 32)

x, y = next(train_ds.as_numpy_iterator())

x.shape, y.shape
# Out:
# ((32, 256, 256, 3), (32, 256, 256, 1))

# %%
valid_ds = make_image_gen(valid_df, VALID_IMG_COUNT).as_numpy_iterator()
valid_x, valid_y = next(valid_ds)
print(valid_x.shape, valid_y.shape)
# Out:
# (900, 256, 256, 3) (900, 256, 256, 1)

# %%
# I use two augmentation Sequential models because if the input image is augmented,
# then the corresponding mask should be augmented too in the same way.
# That's why I use a similar seed for pseudo-random generator.

# Also, I use Resizing
input_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomRotation(factor=0.25, seed=42),  # Rotation range is -45 to 45 degrees
    tf.keras.layers.RandomWidth(factor=0.1, seed=42),  # Width shift range is -10% to 10%
    tf.keras.layers.RandomHeight(factor=0.1, seed=42),  # Height shift range is -10% to 10%
    tf.keras.layers.RandomZoom(height_factor=(-0.1, 0.25), width_factor=(-0.1, 0.25), seed=42),  # Zoom range is 0.9 to 1.25
    tf.keras.layers.RandomFlip("horizontal", seed=42),  # Horizontal flip
    tf.keras.layers.RandomFlip("vertical", seed=42), # Vertical flip
    tf.keras.layers.Resizing(256, 256)
])
output_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomRotation(factor=0.25, seed=42),  # Rotation range is -45 to 45 degrees
    tf.keras.layers.RandomWidth(factor=0.1, seed=42),  # Width shift range is -10% to 10%
    tf.keras.layers.RandomHeight(factor=0.1, seed=42),  # Height shift range is -10% to 10%
    tf.keras.layers.RandomZoom(height_factor=(-0.1, 0.25), width_factor=(-0.1, 0.25), seed=42),  # Zoom range is 0.9 to 1.25
    tf.keras.layers.RandomFlip("horizontal", seed=42),  # Horizontal flip
    tf.keras.layers.RandomFlip("vertical", seed=42), # Vertical flip
    tf.keras.layers.Resizing(256, 256)
])

# %%
def augmentation(input_img, output_img):
    return input_augmentation(input_img), output_augmentation(output_img)

augmented_ds = train_ds.map(augmentation)

# %%
from keras.layers import Input, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate, Dropout
from keras.models import Model
def create_unet(filters=8,
                img_size=(256, 256, 3),
                dropout_rate=0.1,
                kernel_size=(3, 3),
                pool_size=(2, 2),
                strides=(2, 2)):

    inputs = Input(img_size)
    
    # Contraction path
    c1 = Conv2D(filters, kernel_size, activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
    c1 = Dropout(dropout_rate)(c1)
    c1 = Conv2D(filters, kernel_size, activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D(pool_size)(c1)

    c2 = Conv2D(filters * 2, kernel_size, activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(dropout_rate)(c2)
    c2 = Conv2D(filters * 2, kernel_size, activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D(pool_size)(c2)

    c3 = Conv2D(filters * 4, kernel_size, activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(dropout_rate)(c3)
    c3 = Conv2D(filters * 4, kernel_size, activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D(pool_size)(c3)

    c4 = Conv2D(filters * 8, kernel_size, activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(dropout_rate)(c4)
    c4 = Conv2D(filters * 8, kernel_size, activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D(pool_size)(c4)

    # Bridge (1024)
    c5 = Conv2D(filters * 16, kernel_size, activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(dropout_rate)(c5)
    c5 = Conv2D(filters * 16, kernel_size, activation='relu', kernel_initializer='he_normal', padding='same')(c5)

    # Expansive path
    u6 = Conv2DTranspose(filters * 8, pool_size, strides=strides, padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(filters * 8, kernel_size, activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(dropout_rate)(c6)
    c6 = Conv2D(filters * 8, kernel_size, activation='relu', kernel_initializer='he_normal', padding='same')(c6)

    u7 = Conv2DTranspose(filters * 4, pool_size, strides=strides, padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(filters * 4, kernel_size, activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(dropout_rate)(c7)
    c7 = Conv2D(filters * 4, kernel_size, activation='relu', kernel_initializer='he_normal', padding='same')(c7)

    u8 = Conv2DTranspose(filters * 2, pool_size, strides=strides, padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(filters * 2, kernel_size, activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(dropout_rate)(c8)
    c8 = Conv2D(filters * 2, kernel_size, activation='relu', kernel_initializer='he_normal', padding='same')(c8)

    u9 = Conv2DTranspose(filters, pool_size, strides=strides, padding='same')(c8)
    u9 = concatenate([u9, c1])
    c9 = Conv2D(filters, kernel_size, activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(dropout_rate)(c9)
    c9 = Conv2D(filters, kernel_size, activation='relu', kernel_initializer='he_normal', padding='same')(c9)

    outputs = Conv2D(1, (1, 1), activation='sigmoid', padding='same')(c9)

    model = Model(inputs=[inputs], outputs=[outputs], name='unet')
    print(model.summary())

    return model

model = create_unet()
# Out:
# Model: "unet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_10 (InputLayer)       [(None, 256, 256, 3)]        0         []
#
#  conv2d_171 (Conv2D)         (None, 256, 256, 8)          224       ['input_10[0][0]']
#
#  dropout_81 (Dropout)        (None, 256, 256, 8)          0         ['conv2d_171[0][0]']
#
#  conv2d_172 (Conv2D)         (None, 256, 256, 8)          584       ['dropout_81[0][0]']
#
#  max_pooling2d_36 (MaxPooli  (None, 128, 128, 8)          0         ['conv2d_172[0][0]']
#  ng2D)
#
#  conv2d_173 (Conv2D)         (None, 128, 128, 16)         1168      ['max_pooling2d_36[0][0]']
#
#  dropout_82 (Dropout)        (None, 128, 128, 16)         0         ['conv2d_173[0][0]']
#
#  conv2d_174 (Conv2D)         (None, 128, 128, 16)         2320      ['dropout_82[0][0]']
#
#  max_pooling2d_37 (MaxPooli  (None, 64, 64, 16)           0         ['conv2d_174[0][0]']
#  ng2D)
#
#  conv2d_175 (Conv2D)         (None, 64, 64, 32)           4640      ['max_pooling2d_37[0][0]']
#
#  dropout_83 (Dropout)        (None, 64, 64, 32)           0         ['conv2d_175[0][0]']
#
#  conv2d_176 (Conv2D)         (None, 64, 64, 32)           9248      ['dropout_83[0][0]']
#
#  max_pooling2d_38 (MaxPooli  (None, 32, 32, 32)           0         ['conv2d_176[0][0]']
#  ng2D)
#
#  conv2d_177 (Conv2D)         (None, 32, 32, 64)           18496     ['max_pooling2d_38[0][0]']
#
#  dropout_84 (Dropout)        (None, 32, 32, 64)           0         ['conv2d_177[0][0]']
#
#  conv2d_178 (Conv2D)         (None, 32, 32, 64)           36928     ['dropout_84[0][0]']
#
#  max_pooling2d_39 (MaxPooli  (None, 16, 16, 64)           0         ['conv2d_178[0][0]']
#  ng2D)
#
#  conv2d_179 (Conv2D)         (None, 16, 16, 128)          73856     ['max_pooling2d_39[0][0]']
#
#  dropout_85 (Dropout)        (None, 16, 16, 128)          0         ['conv2d_179[0][0]']
#
#  conv2d_180 (Conv2D)         (None, 16, 16, 128)          147584    ['dropout_85[0][0]']
#
#  conv2d_transpose_36 (Conv2  (None, 32, 32, 64)           32832     ['conv2d_180[0][0]']
#  DTranspose)
#
#  concatenate_36 (Concatenat  (None, 32, 32, 128)          0         ['conv2d_transpose_36[0][0]',
#  e)                                                                  'conv2d_178[0][0]']
#
#  conv2d_181 (Conv2D)         (None, 32, 32, 64)           73792     ['concatenate_36[0][0]']
#
#  dropout_86 (Dropout)        (None, 32, 32, 64)           0         ['conv2d_181[0][0]']
#
#  conv2d_182 (Conv2D)         (None, 32, 32, 64)           36928     ['dropout_86[0][0]']
#
#  conv2d_transpose_37 (Conv2  (None, 64, 64, 32)           8224      ['conv2d_182[0][0]']
#  DTranspose)
#
#  concatenate_37 (Concatenat  (None, 64, 64, 64)           0         ['conv2d_transpose_37[0][0]',
#  e)                                                                  'conv2d_176[0][0]']
#
#  conv2d_183 (Conv2D)         (None, 64, 64, 32)           18464     ['concatenate_37[0][0]']
#
#  dropout_87 (Dropout)        (None, 64, 64, 32)           0         ['conv2d_183[0][0]']
#
#  conv2d_184 (Conv2D)         (None, 64, 64, 32)           9248      ['dropout_87[0][0]']
#
#  conv2d_transpose_38 (Conv2  (None, 128, 128, 16)         2064      ['conv2d_184[0][0]']
#  DTranspose)
#
#  concatenate_38 (Concatenat  (None, 128, 128, 32)         0         ['conv2d_transpose_38[0][0]',
#  e)                                                                  'conv2d_174[0][0]']
#
#  conv2d_185 (Conv2D)         (None, 128, 128, 16)         4624      ['concatenate_38[0][0]']
#
#  dropout_88 (Dropout)        (None, 128, 128, 16)         0         ['conv2d_185[0][0]']
#
#  conv2d_186 (Conv2D)         (None, 128, 128, 16)         2320      ['dropout_88[0][0]']
#
#  conv2d_transpose_39 (Conv2  (None, 256, 256, 8)          520       ['conv2d_186[0][0]']
#  DTranspose)
#
#  concatenate_39 (Concatenat  (None, 256, 256, 16)         0         ['conv2d_transpose_39[0][0]',
#  e)                                                                  'conv2d_172[0][0]']
#
#  conv2d_187 (Conv2D)         (None, 256, 256, 8)          1160      ['concatenate_39[0][0]']
#
#  dropout_89 (Dropout)        (None, 256, 256, 8)          0         ['conv2d_187[0][0]']
#
#  conv2d_188 (Conv2D)         (None, 256, 256, 8)          584       ['dropout_89[0][0]']
#
#  conv2d_189 (Conv2D)         (None, 256, 256, 1)          9         ['conv2d_188[0][0]']
#
# ==================================================================================================
# Total params: 485817 (1.85 MB)
# Trainable params: 485817 (1.85 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(patience=10, monitor='val_loss', restore_best_weights=True, verbose=1)

# %%
# Compiling the model
model.compile(optimizer='adam', loss=tf.keras.losses.BinaryFocalCrossentropy(gamma=2.0, from_logits=True), metrics=[dice_coff])

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
history = model.fit(train_ds, epochs=100, verbose=1, callbacks=[early_stopping], 
                    steps_per_epoch=min(MAX_TRAIN_STEPS, len(train_df)//BATCH_SIZE), validation_data=[valid_x, valid_y])
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/backend.py:5805: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Sigmoid activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 2023-12-02 18:01:41.123027: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inunet/dropout_81/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 300/300 [==============================] - 128s 401ms/step - loss: 0.0297 - dice_coff: 0.0540 - val_loss: 0.0050 - val_dice_coff: 0.1427
# Epoch 2/100
# 300/300 [==============================] - 110s 369ms/step - loss: 0.0049 - dice_coff: 0.2126 - val_loss: 0.0039 - val_dice_coff: 0.2518
# Epoch 3/100
# 300/300 [==============================] - 111s 370ms/step - loss: 0.0040 - dice_coff: 0.2768 - val_loss: 0.0034 - val_dice_coff: 0.3138
# Epoch 4/100
# 300/300 [==============================] - 110s 366ms/step - loss: 0.0036 - dice_coff: 0.3080 - val_loss: 0.0032 - val_dice_coff: 0.3347
# Epoch 5/100
# 300/300 [==============================] - 121s 404ms/step - loss: 0.0034 - dice_coff: 0.3341 - val_loss: 0.0029 - val_dice_coff: 0.4003
# Epoch 6/100
# 300/300 [==============================] - 126s 420ms/step - loss: 0.0032 - dice_coff: 0.3626 - val_loss: 0.0035 - val_dice_coff: 0.3279
# Epoch 7/100
# 300/300 [==============================] - 110s 368ms/step - loss: 0.0030 - dice_coff: 0.3904 - val_loss: 0.0026 - val_dice_coff: 0.4231
# Epoch 8/100
# 300/300 [==============================] - 111s 370ms/step - loss: 0.0028 - dice_coff: 0.4093 - val_loss: 0.0025 - val_dice_coff: 0.4523
# Epoch 9/100
# 300/300 [==============================] - 110s 368ms/step - loss: 0.0027 - dice_coff: 0.4362 - val_loss: 0.0025 - val_dice_coff: 0.4753
# Epoch 10/100
# 300/300 [==============================] - 111s 370ms/step - loss: 0.0025 - dice_coff: 0.4619 - val_loss: 0.0024 - val_dice_coff: 0.4485
# Epoch 11/100
# 300/300 [==============================] - 112s 372ms/step - loss: 0.0025 - dice_coff: 0.4714 - val_loss: 0.0022 - val_dice_coff: 0.5035
# Epoch 12/100
# 300/300 [==============================] - 111s 371ms/step - loss: 0.0024 - dice_coff: 0.4891 - val_loss: 0.0021 - val_dice_coff: 0.5312
# Epoch 13/100
# 300/300 [==============================] - 111s 370ms/step - loss: 0.0022 - dice_coff: 0.5160 - val_loss: 0.0021 - val_dice_coff: 0.5517
# Epoch 14/100
# 300/300 [==============================] - 111s 372ms/step - loss: 0.0022 - dice_coff: 0.5297 - val_loss: 0.0020 - val_dice_coff: 0.5065
# Epoch 15/100
# 300/300 [==============================] - 110s 368ms/step - loss: 0.0020 - dice_coff: 0.5479 - val_loss: 0.0021 - val_dice_coff: 0.5453
# Epoch 16/100
# 300/300 [==============================] - 111s 369ms/step - loss: 0.0021 - dice_coff: 0.5344 - val_loss: 0.0020 - val_dice_coff: 0.5411
# Epoch 17/100
# 300/300 [==============================] - 111s 372ms/step - loss: 0.0020 - dice_coff: 0.5630 - val_loss: 0.0019 - val_dice_coff: 0.5805
# Epoch 18/100
# 300/300 [==============================] - 111s 372ms/step - loss: 0.0018 - dice_coff: 0.5933 - val_loss: 0.0018 - val_dice_coff: 0.5891
# Epoch 19/100
# 300/300 [==============================] - 112s 374ms/step - loss: 0.0019 - dice_coff: 0.5827 - val_loss: 0.0018 - val_dice_coff: 0.5778
# Epoch 20/100
# 300/300 [==============================] - 112s 373ms/step - loss: 0.0017 - dice_coff: 0.6023 - val_loss: 0.0018 - val_dice_coff: 0.5893
# Epoch 21/100
# 300/300 [==============================] - 113s 376ms/step - loss: 0.0017 - dice_coff: 0.6119 - val_loss: 0.0019 - val_dice_coff: 0.5534
# Epoch 22/100
# 300/300 [==============================] - 111s 370ms/step - loss: 0.0016 - dice_coff: 0.6272 - val_loss: 0.0016 - val_dice_coff: 0.6289
# Epoch 23/100
# 300/300 [==============================] - 111s 370ms/step - loss: 0.0016 - dice_coff: 0.6304 - val_loss: 0.0019 - val_dice_coff: 0.5636
# Epoch 24/100
# 300/300 [==============================] - 111s 372ms/step - loss: 0.0017 - dice_coff: 0.6205 - val_loss: 0.0018 - val_dice_coff: 0.6363
# Epoch 25/100
# 300/300 [==============================] - 109s 365ms/step - loss: 0.0015 - dice_coff: 0.6477 - val_loss: 0.0016 - val_dice_coff: 0.6494
# Epoch 26/100
# 300/300 [==============================] - 109s 364ms/step - loss: 0.0016 - dice_coff: 0.6321 - val_loss: 0.0015 - val_dice_coff: 0.6379
# Epoch 27/100
# 300/300 [==============================] - 110s 368ms/step - loss: 0.0014 - dice_coff: 0.6598 - val_loss: 0.0016 - val_dice_coff: 0.6523
# Epoch 28/100
# 300/300 [==============================] - 109s 366ms/step - loss: 0.0014 - dice_coff: 0.6735 - val_loss: 0.0017 - val_dice_coff: 0.6692
# Epoch 29/100
# 300/300 [==============================] - 111s 369ms/step - loss: 0.0015 - dice_coff: 0.6529 - val_loss: 0.0016 - val_dice_coff: 0.6361
# Epoch 30/100
# 300/300 [==============================] - 114s 380ms/step - loss: 0.0013 - dice_coff: 0.6777 - val_loss: 0.0015 - val_dice_coff: 0.6751
# Epoch 31/100
# 300/300 [==============================] - 113s 376ms/step - loss: 0.0014 - dice_coff: 0.6688 - val_loss: 0.0016 - val_dice_coff: 0.6442
# Epoch 32/100
# 300/300 [==============================] - 111s 369ms/step - loss: 0.0014 - dice_coff: 0.6759 - val_loss: 0.0015 - val_dice_coff: 0.6811
# Epoch 33/100
# 300/300 [==============================] - 113s 376ms/step - loss: 0.0014 - dice_coff: 0.6737 - val_loss: 0.0016 - val_dice_coff: 0.6938
# Epoch 34/100
# 300/300 [==============================] - 112s 375ms/step - loss: 0.0013 - dice_coff: 0.6861 - val_loss: 0.0015 - val_dice_coff: 0.6634
# Epoch 35/100
# 300/300 [==============================] - 114s 379ms/step - loss: 0.0013 - dice_coff: 0.6936 - val_loss: 0.0016 - val_dice_coff: 0.6696
# Epoch 36/100
# 300/300 [==============================] - 113s 377ms/step - loss: 0.0013 - dice_coff: 0.7006 - val_loss: 0.0015 - val_dice_coff: 0.6496
# Epoch 37/100
# 300/300 [==============================] - 114s 382ms/step - loss: 0.0013 - dice_coff: 0.6994 - val_loss: 0.0016 - val_dice_coff: 0.6549
# Epoch 38/100
# 300/300 [==============================] - 112s 375ms/step - loss: 0.0013 - dice_coff: 0.6920 - val_loss: 0.0017 - val_dice_coff: 0.6495
# Epoch 39/100
# 300/300 [==============================] - 112s 375ms/step - loss: 0.0013 - dice_coff: 0.6893 - val_loss: 0.0018 - val_dice_coff: 0.6233
# Epoch 40/100
# 300/300 [==============================] - 113s 376ms/step - loss: 0.0013 - dice_coff: 0.6968 - val_loss: 0.0015 - val_dice_coff: 0.6770
# Epoch 41/100
# 300/300 [==============================] - 110s 368ms/step - loss: 0.0012 - dice_coff: 0.7188 - val_loss: 0.0016 - val_dice_coff: 0.6803
# Epoch 42/100
# 300/300 [==============================] - 116s 386ms/step - loss: 0.0014 - dice_coff: 0.6842 - val_loss: 0.0016 - val_dice_coff: 0.6468
# Epoch 43/100
# 300/300 [==============================] - 111s 372ms/step - loss: 0.0012 - dice_coff: 0.7073 - val_loss: 0.0016 - val_dice_coff: 0.6727
# Epoch 44/100
# 300/300 [==============================] - ETA: 0s - loss: 0.0013 - dice_coff: 0.6999Restoring model weights from the end of the best epoch: 34.
# 300/300 [==============================] - 110s 368ms/step - loss: 0.0013 - dice_coff: 0.6999 - val_loss: 0.0015 - val_dice_coff: 0.6750
# Epoch 44: early stopping

# %%
# I used different file formats such as h5, and keras
model.save('model.keras')

# %%
# Loading saved model
loaded_model = tf.keras.models.load_model('model.h5', custom_objects={"dice_coff": dice_coff})
loaded_model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\glebl\PycharmProjects\Airbus-Ship-Detection-Challenge\test_ai\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# WARNING:tensorflow:From C:\Users\glebl\PycharmProjects\Airbus-Ship-Detection-Challenge\test_ai\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# Model: "unet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_10 (InputLayer)       [(None, 256, 256, 3)]        0         []
#
#  conv2d_171 (Conv2D)         (None, 256, 256, 8)          224       ['input_10[0][0]']
#
#  dropout_81 (Dropout)        (None, 256, 256, 8)          0         ['conv2d_171[0][0]']
#
#  conv2d_172 (Conv2D)         (None, 256, 256, 8)          584       ['dropout_81[0][0]']
#
#  max_pooling2d_36 (MaxPooli  (None, 128, 128, 8)          0         ['conv2d_172[0][0]']
#  ng2D)
#
#  conv2d_173 (Conv2D)         (None, 128, 128, 16)         1168      ['max_pooling2d_36[0][0]']
#
#  dropout_82 (Dropout)        (None, 128, 128, 16)         0         ['conv2d_173[0][0]']
#
#  conv2d_174 (Conv2D)         (None, 128, 128, 16)         2320      ['dropout_82[0][0]']
#
#  max_pooling2d_37 (MaxPooli  (None, 64, 64, 16)           0         ['conv2d_174[0][0]']
#  ng2D)
#
#  conv2d_175 (Conv2D)         (None, 64, 64, 32)           4640      ['max_pooling2d_37[0][0]']
#
#  dropout_83 (Dropout)        (None, 64, 64, 32)           0         ['conv2d_175[0][0]']
#
#  conv2d_176 (Conv2D)         (None, 64, 64, 32)           9248      ['dropout_83[0][0]']
#
#  max_pooling2d_38 (MaxPooli  (None, 32, 32, 32)           0         ['conv2d_176[0][0]']
#  ng2D)
#
#  conv2d_177 (Conv2D)         (None, 32, 32, 64)           18496     ['max_pooling2d_38[0][0]']
#
#  dropout_84 (Dropout)        (None, 32, 32, 64)           0         ['conv2d_177[0][0]']
#
#  conv2d_178 (Conv2D)         (None, 32, 32, 64)           36928     ['dropout_84[0][0]']
#
#  max_pooling2d_39 (MaxPooli  (None, 16, 16, 64)           0         ['conv2d_178[0][0]']
#  ng2D)
#
#  conv2d_179 (Conv2D)         (None, 16, 16, 128)          73856     ['max_pooling2d_39[0][0]']
#
#  dropout_85 (Dropout)        (None, 16, 16, 128)          0         ['conv2d_179[0][0]']
#
#  conv2d_180 (Conv2D)         (None, 16, 16, 128)          147584    ['dropout_85[0][0]']
#
#  conv2d_transpose_36 (Conv2  (None, 32, 32, 64)           32832     ['conv2d_180[0][0]']
#  DTranspose)
#
#  concatenate_36 (Concatenat  (None, 32, 32, 128)          0         ['conv2d_transpose_36[0][0]',
#  e)                                                                  'conv2d_178[0][0]']
#
#  conv2d_181 (Conv2D)         (None, 32, 32, 64)           73792     ['concatenate_36[0][0]']
#
#  dropout_86 (Dropout)        (None, 32, 32, 64)           0         ['conv2d_181[0][0]']
#
#  conv2d_182 (Conv2D)         (None, 32, 32, 64)           36928     ['dropout_86[0][0]']
#
#  conv2d_transpose_37 (Conv2  (None, 64, 64, 32)           8224      ['conv2d_182[0][0]']
#  DTranspose)
#
#  concatenate_37 (Concatenat  (None, 64, 64, 64)           0         ['conv2d_transpose_37[0][0]',
#  e)                                                                  'conv2d_176[0][0]']
#
#  conv2d_183 (Conv2D)         (None, 64, 64, 32)           18464     ['concatenate_37[0][0]']
#
#  dropout_87 (Dropout)        (None, 64, 64, 32)           0         ['conv2d_183[0][0]']
#
#  conv2d_184 (Conv2D)         (None, 64, 64, 32)           9248      ['dropout_87[0][0]']
#
#  conv2d_transpose_38 (Conv2  (None, 128, 128, 16)         2064      ['conv2d_184[0][0]']
#  DTranspose)
#
#  concatenate_38 (Concatenat  (None, 128, 128, 32)         0         ['conv2d_transpose_38[0][0]',
#  e)                                                                  'conv2d_174[0][0]']
#
#  conv2d_185 (Conv2D)         (None, 128, 128, 16)         4624      ['concatenate_38[0][0]']
#
#  dropout_88 (Dropout)        (None, 128, 128, 16)         0         ['conv2d_185[0][0]']
#
#  conv2d_186 (Conv2D)         (None, 128, 128, 16)         2320      ['dropout_88[0][0]']
#
#  conv2d_transpose_39 (Conv2  (None, 256, 256, 8)          520       ['conv2d_186[0][0]']
#  DTranspose)
#
#  concatenate_39 (Concatenat  (None, 256, 256, 16)         0         ['conv2d_transpose_39[0][0]',
#  e)                                                                  'conv2d_172[0][0]']
#
#  conv2d_187 (Conv2D)         (None, 256, 256, 8)          1160      ['concatenate_39[0][0]']
#
#  dropout_89 (Dropout)        (None, 256, 256, 8)          0         ['conv2d_187[0][0]']
#
#  conv2d_188 (Conv2D)         (None, 256, 256, 8)          584       ['dropout_89[0][0]']
#
#  conv2d_189 (Conv2D)         (None, 256, 256, 1)          9         ['conv2d_188[0][0]']
#
# ==================================================================================================
# Total params: 485817 (1.85 MB)
# Trainable params: 485817 (1.85 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
predicted = loaded_model.predict(valid_x)
# Out:
# 29/29 [==============================] - 9s 264ms/step

# %%
# Predicted > threshold. I used different thresholds, and the most obvious choice is 0.5 because this project
# is binary segmentation project (i.e. there are only two classes - background and ship).
# I noticed that it's possible to lower threshold and predicted results
predictions = np.where(predicted > 0.35, 1, 0)
predictions.shape
# Out:
# (900, 256, 256, 1)

# %%
predictions[0].shape
# Out:
# (256, 256, 1)

# %%
def visualize_validation_predictions():
    plt.figure(figsize=(12, 10))
    
    random_index = np.random.randint(0, 900)
    # Display the original image
    plt.subplot(1, 3, 1)
    plt.grid(False)
    plt.imshow(valid_x[random_index])
    plt.title('Original Image')
    
    # Display the ground truth mask
    plt.subplot(1, 3, 2)
    plt.grid(False)
    plt.imshow(np.squeeze(valid_y[random_index]), cmap='gray')
    plt.title('Ground Truth Mask')
    
    # Display the predicted mask
    plt.subplot(1, 3, 3)
    plt.grid(False)
    plt.imshow(np.squeeze(predictions[random_index]), cmap='gray')
    plt.title('Predicted Mask')
        
    
    plt.show()
    
visualize_validation_predictions()
